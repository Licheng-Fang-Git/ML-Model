# %% [markdown]
# # **Exploratory Data Analysis**
#
#         - Method used to analyze data sets and summarize their main characteristics
#
#         - Transforming and cleaning data to make it more useful
#
#         - Makeing it easier to discover patterens, spot anomalies, checking assumptions or even testing hypothesis
#
# # **Two Subgroups of EDA**
#
#         - Uni-Variat
#
#         - Multi-Variat
#
# # **Uni-Variat Analysis**
#
#         - Purpose: Describe the data and find patterns that exist within it.
#
#         - Non Graphical:
#
#                 - Since it deals with a single variable, its purpose is to describe the data's central tendency (mean, median) and spread (variance, standard deviation) without exploring relationships or causality
#
#         - Graphical:
#
#                 - Common Types of graphs include:
#
#                         - Stem and Leaf Plots which shows all the data values and the shape of distribution
#
#                         - Histograms/Bar Plot which each bar represents the porportion of cases for a range of values
#
#                         - Box plot is a fantastic graphical tool for univariate analysis as it clearly shows the median, quartiles, and outliers.
#
#
#
# # **Multi-Variat Analysis**
#
#         - Non Graphical:
#
#                 - Shows relationship between two or more varaibles of data through cross tabulation or statistics
#
#         - Multivariate Graphics:
#
#                 - Group bar charts which each group represents one level of the other variable
#
#                 - Bubble charts, heat maps and run charts
#
#                 - Bubble Charts and Heat Maps: Useful for visualizing relationships among three or more variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
from scipy.stats import linregress

print("Hello")
# Out:
# Collecting scipy
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\lfang\ml-model\.venv\lib\site-packages (from scipy) (2.3.2)
# Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.1
# Hello

# %% [markdown]
# # **Step 1: Data Understanding**

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1thMQ4ndtgzyEM6qfoA2tfrt3MEzZY2CtxhjpCTNcS0U/gviz/tq?tqx=out:csv&sheet=Content")
print('https://docs.google.com/spreadsheets/d/1thMQ4ndtgzyEM6qfoA2tfrt3MEzZY2CtxhjpCTNcS0U/gviz/tq?tqx=out:csv&sheet=Content')
print(df)
# Out:
# https://docs.google.com/spreadsheets/d/1thMQ4ndtgzyEM6qfoA2tfrt3MEzZY2CtxhjpCTNcS0U/gviz/tq?tqx=out:csv&sheet=Content
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Post title  \
# 0                                                                                                                                                                                                       𝗣𝗼𝗸𝗲𝗿 𝗮𝗻𝗱 𝗧𝗿𝗮𝗱𝗶𝗻𝗴: 𝗚𝗮𝗺𝗲𝘀 𝗼𝗳 𝗦𝗸𝗶𝗹𝗹, 𝗦𝘁𝗿𝗮𝘁𝗲𝗴𝘆, 𝗮𝗻𝗱 𝗥𝗶𝘀𝗸\n \n Our interns recently gathered online for a poker tournament—an opportunity for friendly competition and team connection in a different setting.\n \n Like trading, poker requires focus, discipline, calculated risk-taking, and the ability to make decisions under pressure. The tournament was not only a chance to enjoy some friendly competition, but also a reminder of the skills that drive performance in markets.\n \n #TrilliumTrading #Teamwork #Culture #Poker #Trading
# 1                                                        𝗠𝗲𝗲𝘁 𝗟𝗶𝗰𝗵𝗲𝗻𝗴 𝗙𝗮𝗻𝗴!\n \n Licheng Fang joined Trillium this summer through the Futures and Options program. As a rising senior at Brooklyn Technical High School, he majors in software engineering and is passionate about exploring the intersection of technology and finance.\n \n Through his internship at Trillium, Licheng has contributed to projects across analytics, web development, and programming—building skills that align with his goal of becoming a software engineer.\n \n We’re excited to see Licheng continue building momentum as he takes the next steps toward a future in tech.\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 2                                                                                                                                                                                                                                                                                                                                                                                                                    𝗛𝗮𝗽𝗽𝘆 𝗡𝗮𝘁𝗶𝗼𝗻𝗮𝗹 𝗜𝗻𝘁𝗲𝗿𝗻 𝗗𝗮𝘆!\n \n We’re excited to introduce our Summer 2025 Trading Interns—exceptional individuals who bring energy, curiosity, and ambition to our trading floor.\n \n Meet the next generation of talent.\n \n #TrilliumTrading #NationalInternDay #Internship #Mentorship #Trading #Finance #Markets #Technology
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      𝗦𝗲𝘁 𝗨𝗽 𝗳𝗼𝗿 𝗦𝘂𝗰𝗰𝗲𝘀𝘀 \n \n Each of our Summer 2025 interns received Trillium swag—equipping them with the essentials to start strong and look sharp. \n \n Take a look inside!\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 4                                                                                                                                                                                                  𝗕𝗲𝗵𝗶𝗻𝗱-𝘁𝗵𝗲-𝗦𝗰𝗲𝗻𝗲𝘀 𝘄𝗶𝘁𝗵 𝗼𝘂𝗿 𝗦𝘂𝗺𝗺𝗲𝗿 𝗧𝗿𝗮𝗱𝗶𝗻𝗴 𝗜𝗻𝘁𝗲𝗿𝗻𝘀: 𝗖𝗮𝘀𝗲 𝗦𝘁𝘂𝗱𝗶𝗲𝘀 \n \n This week, our trading interns analyzed real market scenarios through case studies—recreating stock moves, examining catalysts, and evaluating trading setups.\n \n Each presentation sharpened their market instincts and decision-making skills, preparing them to embrace the mindset of a trader.\n \n We’re excited to see what lies ahead as they continue to grow and push boundaries.\n \n #TrilliumTrading #Finance #Trading #Markets #Internship #Career #CaseStudies
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 189                                                                                                                                                                                                                                                                                                                                                                                                                              ⛳ Our summer trading interns in New York got to enjoy time together outside of the office, teeing it up for a round at Battleground Country Club. \n \n We take pride in extending all who join the firm a complimentary club membership as a perk of being part of the Trillium team.\n \n #Internship #Golf #Trillium
# 190  🛎️ Ringing in 2️⃣0️⃣ Years of Trillium at Nasdaq \n \n For 20 years, we have been dedicated to building long and lucrative trading careers.\n \n For 20 years, our expert engineers have been building and improving our powerful proprietary trading technology.\n \n For 20 years, we've been risking the firm's capital, allowing our traders to focus solely on trading without risking their own funds.\n \n For 20 years, we have been excelling and prospering under all market conditions.\n \n Congratulations to the entire team for reaching this tremendous milestone. We are so excited to see what the next 20 years will bring.\n  \n \n #trillium #closingbell #nasdaq #proprietarytrading\n 📸 Photography courtesy of Nasdaq, Inc.
# 191                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Our Miami office enjoyed an outing at Rosa Sky Rooftop, followed by dinner at La Wagyeria Steakhouse\n \n #Internship #Mentors #Trillium
# 192                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Our summer interns were invited to tour the trading floor at NYSE and witness the iconic Opening Bell ceremony. They enjoyed front-row seats to CNBC's Squawk on the Street, followed by a visit to the famous Charging Bull. \n #internship #NYSE #Trillium
# 193                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        While shadowing their mentors, students from Science Park High School got a firsthand experience of what it’s like to be a trader at Trillium.\n \n #Trillium #Trading #Mentors MENTOR Newark
#
#                                                                     Post link  \
# 0    https://www.linkedin.com/feed/update/urn:li:activity:7358512525543428098
# 1    https://www.linkedin.com/feed/update/urn:li:activity:7357080515188776960
# 2    https://www.linkedin.com/feed/update/urn:li:activity:7356746078752309249
# 3    https://www.linkedin.com/feed/update/urn:li:activity:7356360578266734593
# 4    https://www.linkedin.com/feed/update/urn:li:activity:7354571979707797505
# ..                                                                        ...
# 189  https://www.linkedin.com/feed/update/urn:li:activity:7102388467149545472
# 190  https://www.linkedin.com/feed/update/urn:li:activity:7099489355613814784
# 191  https://www.linkedin.com/feed/update/urn:li:activity:7097603451597008896
# 192  https://www.linkedin.com/feed/update/urn:li:activity:7095021167828185088
# 193  https://www.linkedin.com/feed/update/urn:li:activity:7092892408274694144
#
#     Post type  Campaign name           Posted by Created date  \
# 0     Organic            NaN  Rafaela Kapitanker     8/5/2025
# 1     Organic            NaN  Rafaela Kapitanker     8/1/2025
# 2     Organic            NaN  Rafaela Kapitanker    7/31/2025
# 3     Organic            NaN  Rafaela Kapitanker    7/30/2025
# 4     Organic            NaN  Rafaela Kapitanker    7/25/2025
# ..        ...            ...                 ...          ...
# 189   Organic            NaN        Andrew Kissh    8/29/2023
# 190   Organic            NaN        Andrew Kissh    8/21/2023
# 191   Organic            NaN        Andrew Kissh    8/16/2023
# 192   Organic            NaN        Andrew Kissh     8/9/2023
# 193   Organic            NaN        Andrew Kissh     8/3/2023
#
#      Campaign start date  Campaign end date       Audience  Impressions  ...  \
# 0                    NaN                NaN  All followers         3954  ...
# 1                    NaN                NaN  All followers         5259  ...
# 2                    NaN                NaN  All followers        12248  ...
# 3                    NaN                NaN  All followers         7812  ...
# 4                    NaN                NaN  All followers         5247  ...
# ..                   ...                ...            ...          ...  ...
# 189                  NaN                NaN  All followers         2453  ...
# 190                  NaN                NaN  All followers         2741  ...
# 191                  NaN                NaN  All followers         2015  ...
# 192                  NaN                NaN  All followers         2601  ...
# 193                  NaN                NaN  All followers         2732  ...
#
#      Year  Month & Year  Day of the week  Time of Posting  Number of Post  \
# 0    2025      Aug 2025              Tue      11:01:00 AM               1
# 1    2025      Aug 2025              Fri      12:11:00 PM               1
# 2    2025      Jul 2025              Thu       2:02:00 PM               1
# 3    2025      Jul 2025              Wed      12:30:00 PM               1
# 4    2025      Jul 2025              Fri       2:03:00 PM               1
# ..    ...           ...              ...              ...             ...
# 189  2023      Aug 2023              Tue       4:36:00 PM               1
# 190  2023      Aug 2023              Mon       4:36:00 PM               1
# 191  2023      Aug 2023              Wed      11:42:00 AM               1
# 192  2023      Aug 2023              Wed       8:41:00 AM               1
# 193  2023      Aug 2023              Thu      11:42:00 AM               1
#
#      Emoji  Emoji Value  Type Emoji  Type of Post Interval Times
# 0    False          NaN           🚫         image       11:00 AM
# 1    False          NaN           🚫          text       12:00 PM
# 2    False          NaN           🚫         video        2:00 PM
# 3    False          NaN           🚫         video       12:30 PM
# 4    False          NaN           🚫         image        2:00 PM
# ..     ...          ...         ...           ...            ...
# 189   True            ⛳           ⛳           NaN        4:30 PM
# 190   True            📸           📸           NaN        4:30 PM
# 191  False          NaN           🚫           NaN       11:30 AM
# 192  False          NaN           🚫           NaN        8:30 AM
# 193  False          NaN           🚫           NaN       11:30 AM
#
# [194 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Post title', 'Post link', 'Post type', 'Campaign name', 'Posted by',
#        'Created date', 'Campaign start date', 'Campaign end date', 'Audience',
#        'Impressions', 'Views', 'Offsite Views', 'Clicks',
#        'Click through rate (CTR)', 'Likes', 'Comments', 'Reposts', 'Follows',
#        'Engagement rate', 'Content Type', 'Post Title', 'Category',
#        'Sub-Category', 'Year', 'Month & Year', 'Day of the week',
#        'Time of Posting', 'Number of Post', 'Emoji', 'Emoji Value',
#        'Type Emoji', 'Type of Post', 'Interval Times'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Campaign name  Campaign start date  Campaign end date   Impressions  \
# count            0.0                  0.0                0.0    194.000000
# mean             NaN                  NaN                NaN   4395.190722
# std              NaN                  NaN                NaN   3570.728613
# min              NaN                  NaN                NaN    923.000000
# 25%              NaN                  NaN                NaN   2026.000000
# 50%              NaN                  NaN                NaN   3191.500000
# 75%              NaN                  NaN                NaN   5613.250000
# max              NaN                  NaN                NaN  20272.000000
#
#              Views  Offsite Views       Clicks  Click through rate (CTR)  \
# count    25.000000            0.0   194.000000                194.000000
# mean   1899.480000            NaN   749.618557                  0.146134
# std    1381.534477            NaN   915.815732                  0.124068
# min     554.000000            NaN    12.000000                  0.010000
# 25%    1129.000000            NaN   112.500000                  0.050000
# 50%    1316.000000            NaN   379.500000                  0.090000
# 75%    2266.000000            NaN  1062.250000                  0.220000
# max    7050.000000            NaN  5140.000000                  0.560000
#
#             Likes    Comments     Reposts  Follows  Engagement rate  \
# count  194.000000  194.000000  194.000000      0.0       194.000000
# mean    44.056701    2.252577    1.164948      NaN         0.159072
# std     26.550214    3.111589    1.597799      NaN         0.123595
# min      4.000000    0.000000    0.000000      NaN         0.020000
# 25%     25.000000    0.000000    0.000000      NaN         0.070000
# 50%     38.000000    1.000000    1.000000      NaN         0.110000
# 75%     57.000000    3.000000    2.000000      NaN         0.230000
# max    152.000000   26.000000   11.000000      NaN         0.570000
#
#               Year  Number of Post
# count   194.000000           194.0
# mean   2024.175258             1.0
# std       0.651985             0.0
# min    2023.000000             1.0
# 25%    2024.000000             1.0
# 50%    2024.000000             1.0
# 75%    2025.000000             1.0
# max    2025.000000             1.0

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Post title  \
# 0                                                                                                                                                 𝗣𝗼𝗸𝗲𝗿 𝗮𝗻𝗱 𝗧𝗿𝗮𝗱𝗶𝗻𝗴: 𝗚𝗮𝗺𝗲𝘀 𝗼𝗳 𝗦𝗸𝗶𝗹𝗹, 𝗦𝘁𝗿𝗮𝘁𝗲𝗴𝘆, 𝗮𝗻𝗱 𝗥𝗶𝘀𝗸\n \n Our interns recently gathered online for a poker tournament—an opportunity for friendly competition and team connection in a different setting.\n \n Like trading, poker requires focus, discipline, calculated risk-taking, and the ability to make decisions under pressure. The tournament was not only a chance to enjoy some friendly competition, but also a reminder of the skills that drive performance in markets.\n \n #TrilliumTrading #Teamwork #Culture #Poker #Trading
# 1  𝗠𝗲𝗲𝘁 𝗟𝗶𝗰𝗵𝗲𝗻𝗴 𝗙𝗮𝗻𝗴!\n \n Licheng Fang joined Trillium this summer through the Futures and Options program. As a rising senior at Brooklyn Technical High School, he majors in software engineering and is passionate about exploring the intersection of technology and finance.\n \n Through his internship at Trillium, Licheng has contributed to projects across analytics, web development, and programming—building skills that align with his goal of becoming a software engineer.\n \n We’re excited to see Licheng continue building momentum as he takes the next steps toward a future in tech.\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 2                                                                                                                                                                                                                                                                                                                                                              𝗛𝗮𝗽𝗽𝘆 𝗡𝗮𝘁𝗶𝗼𝗻𝗮𝗹 𝗜𝗻𝘁𝗲𝗿𝗻 𝗗𝗮𝘆!\n \n We’re excited to introduce our Summer 2025 Trading Interns—exceptional individuals who bring energy, curiosity, and ambition to our trading floor.\n \n Meet the next generation of talent.\n \n #TrilliumTrading #NationalInternDay #Internship #Mentorship #Trading #Finance #Markets #Technology
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                𝗦𝗲𝘁 𝗨𝗽 𝗳𝗼𝗿 𝗦𝘂𝗰𝗰𝗲𝘀𝘀 \n \n Each of our Summer 2025 interns received Trillium swag—equipping them with the essentials to start strong and look sharp. \n \n Take a look inside!\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 4                                                                                                                                            𝗕𝗲𝗵𝗶𝗻𝗱-𝘁𝗵𝗲-𝗦𝗰𝗲𝗻𝗲𝘀 𝘄𝗶𝘁𝗵 𝗼𝘂𝗿 𝗦𝘂𝗺𝗺𝗲𝗿 𝗧𝗿𝗮𝗱𝗶𝗻𝗴 𝗜𝗻𝘁𝗲𝗿𝗻𝘀: 𝗖𝗮𝘀𝗲 𝗦𝘁𝘂𝗱𝗶𝗲𝘀 \n \n This week, our trading interns analyzed real market scenarios through case studies—recreating stock moves, examining catalysts, and evaluating trading setups.\n \n Each presentation sharpened their market instincts and decision-making skills, preparing them to embrace the mindset of a trader.\n \n We’re excited to see what lies ahead as they continue to grow and push boundaries.\n \n #TrilliumTrading #Finance #Trading #Markets #Internship #Career #CaseStudies
#
#                                                                   Post link  \
# 0  https://www.linkedin.com/feed/update/urn:li:activity:7358512525543428098
# 1  https://www.linkedin.com/feed/update/urn:li:activity:7357080515188776960
# 2  https://www.linkedin.com/feed/update/urn:li:activity:7356746078752309249
# 3  https://www.linkedin.com/feed/update/urn:li:activity:7356360578266734593
# 4  https://www.linkedin.com/feed/update/urn:li:activity:7354571979707797505
#
#   Post type  Campaign name           Posted by Created date  \
# 0   Organic            NaN  Rafaela Kapitanker     8/5/2025
# 1   Organic            NaN  Rafaela Kapitanker     8/1/2025
# 2   Organic            NaN  Rafaela Kapitanker    7/31/2025
# 3   Organic            NaN  Rafaela Kapitanker    7/30/2025
# 4   Organic            NaN  Rafaela Kapitanker    7/25/2025
#
#    Campaign start date  Campaign end date       Audience  Impressions  ...  \
# 0                  NaN                NaN  All followers         3954  ...
# 1                  NaN                NaN  All followers         5259  ...
# 2                  NaN                NaN  All followers        12248  ...
# 3                  NaN                NaN  All followers         7812  ...
# 4                  NaN                NaN  All followers         5247  ...
#
#    Year  Month & Year  Day of the week  Time of Posting  Number of Post  \
# 0  2025      Aug 2025              Tue      11:01:00 AM               1
# 1  2025      Aug 2025              Fri      12:11:00 PM               1
# 2  2025      Jul 2025              Thu       2:02:00 PM               1
# 3  2025      Jul 2025              Wed      12:30:00 PM               1
# 4  2025      Jul 2025              Fri       2:03:00 PM               1
#
#    Emoji  Emoji Value  Type Emoji  Type of Post Interval Times
# 0  False          NaN           🚫         image       11:00 AM
# 1  False          NaN           🚫          text       12:00 PM
# 2  False          NaN           🚫         video        2:00 PM
# 3  False          NaN           🚫         video       12:30 PM
# 4  False          NaN           🚫         image        2:00 PM
#
# [5 rows x 33 columns]

# %% [markdown]
# # **Step 2: Data Preperation**

# %%
df = df[['Post title', 'Post link', 'Created date', 'Impressions', 'Clicks',
       'Click through rate (CTR)', 'Likes', 'Comments',
       'Engagement rate', 'Category',
       'Sub-Category', 'Year', 'Month & Year', 'Day of the week',
       'Time of Posting', 'Emoji', 'Type of Post', 'Interval Times']].copy()

# %%
df.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Post title  \
# 0                                                                                                                                                 𝗣𝗼𝗸𝗲𝗿 𝗮𝗻𝗱 𝗧𝗿𝗮𝗱𝗶𝗻𝗴: 𝗚𝗮𝗺𝗲𝘀 𝗼𝗳 𝗦𝗸𝗶𝗹𝗹, 𝗦𝘁𝗿𝗮𝘁𝗲𝗴𝘆, 𝗮𝗻𝗱 𝗥𝗶𝘀𝗸\n \n Our interns recently gathered online for a poker tournament—an opportunity for friendly competition and team connection in a different setting.\n \n Like trading, poker requires focus, discipline, calculated risk-taking, and the ability to make decisions under pressure. The tournament was not only a chance to enjoy some friendly competition, but also a reminder of the skills that drive performance in markets.\n \n #TrilliumTrading #Teamwork #Culture #Poker #Trading
# 1  𝗠𝗲𝗲𝘁 𝗟𝗶𝗰𝗵𝗲𝗻𝗴 𝗙𝗮𝗻𝗴!\n \n Licheng Fang joined Trillium this summer through the Futures and Options program. As a rising senior at Brooklyn Technical High School, he majors in software engineering and is passionate about exploring the intersection of technology and finance.\n \n Through his internship at Trillium, Licheng has contributed to projects across analytics, web development, and programming—building skills that align with his goal of becoming a software engineer.\n \n We’re excited to see Licheng continue building momentum as he takes the next steps toward a future in tech.\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 2                                                                                                                                                                                                                                                                                                                                                              𝗛𝗮𝗽𝗽𝘆 𝗡𝗮𝘁𝗶𝗼𝗻𝗮𝗹 𝗜𝗻𝘁𝗲𝗿𝗻 𝗗𝗮𝘆!\n \n We’re excited to introduce our Summer 2025 Trading Interns—exceptional individuals who bring energy, curiosity, and ambition to our trading floor.\n \n Meet the next generation of talent.\n \n #TrilliumTrading #NationalInternDay #Internship #Mentorship #Trading #Finance #Markets #Technology
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                𝗦𝗲𝘁 𝗨𝗽 𝗳𝗼𝗿 𝗦𝘂𝗰𝗰𝗲𝘀𝘀 \n \n Each of our Summer 2025 interns received Trillium swag—equipping them with the essentials to start strong and look sharp. \n \n Take a look inside!\n \n #TrilliumTrading #Internship #Mentorship #Trading #Finance #Markets #Technology
# 4                                                                                                                                            𝗕𝗲𝗵𝗶𝗻𝗱-𝘁𝗵𝗲-𝗦𝗰𝗲𝗻𝗲𝘀 𝘄𝗶𝘁𝗵 𝗼𝘂𝗿 𝗦𝘂𝗺𝗺𝗲𝗿 𝗧𝗿𝗮𝗱𝗶𝗻𝗴 𝗜𝗻𝘁𝗲𝗿𝗻𝘀: 𝗖𝗮𝘀𝗲 𝗦𝘁𝘂𝗱𝗶𝗲𝘀 \n \n This week, our trading interns analyzed real market scenarios through case studies—recreating stock moves, examining catalysts, and evaluating trading setups.\n \n Each presentation sharpened their market instincts and decision-making skills, preparing them to embrace the mindset of a trader.\n \n We’re excited to see what lies ahead as they continue to grow and push boundaries.\n \n #TrilliumTrading #Finance #Trading #Markets #Internship #Career #CaseStudies
#
#                                                                   Post link  \
# 0  https://www.linkedin.com/feed/update/urn:li:activity:7358512525543428098
# 1  https://www.linkedin.com/feed/update/urn:li:activity:7357080515188776960
# 2  https://www.linkedin.com/feed/update/urn:li:activity:7356746078752309249
# 3  https://www.linkedin.com/feed/update/urn:li:activity:7356360578266734593
# 4  https://www.linkedin.com/feed/update/urn:li:activity:7354571979707797505
#
#   Created date  Impressions  Clicks  Click through rate (CTR)  Likes  \
# 0     8/5/2025         3954     342                      0.09     59
# 1     8/1/2025         5259    2013                      0.48     28
# 2    7/31/2025        12248    1404                      0.13     86
# 3    7/30/2025         7812     594                      0.08     68
# 4    7/25/2025         5247     213                      0.07     37
#
#    Comments  Engagement rate        Category           Sub-Category  Year  \
# 0         4             0.10      Internship     Field trips/events  2025
# 1         2             0.49  Trillium Cares             Spotlights  2025
# 2         7             0.14      Internship  NFL Style Intro Video  2025
# 3         6             0.09      Internship     Field trips/events  2025
# 4         1             0.08      Internship     BTS - Case Studies  2025
#
#   Month & Year Day of the week Time of Posting  Emoji Type of Post  \
# 0     Aug 2025             Tue     11:01:00 AM  False        image
# 1     Aug 2025             Fri     12:11:00 PM  False         text
# 2     Jul 2025             Thu      2:02:00 PM  False        video
# 3     Jul 2025             Wed     12:30:00 PM  False        video
# 4     Jul 2025             Fri      2:03:00 PM  False        image
#
#   Interval Times
# 0       11:00 AM
# 1       12:00 PM
# 2        2:00 PM
# 3       12:30 PM
# 4        2:00 PM

# %% [markdown]
# # **Step 3: Feature Understanding**

# %%
# Convert the Time Intervals to hour only
# def time_to_hours(t):
#     return pd.to_datetime(t, format="%I:%M %p").hour + pd.to_datetime(t, format="%I:%M %p").minute / 60

# df['Interval Times'] = df['Interval Times'].apply(time_to_hours)

plt.figure(figsize=(15, 6))
sns.regplot(data=df, x='Interval Times', y='Impressions', scatter_kws={'alpha': 0.5, 'color': 'red'}, line_kws={'color': 'blue'})
plt.xticks(range(0, 24), [f"{h % 12 or 12} {'AM' if h < 12 else 'PM'}" for h in range(0, 24)])
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Overall Relationship
# The blue regression line shows a slight positive slope — meaning posts made later in the day tend to get a bit more impressions on average.
#
# However, the confidence interval (blue shaded area) is wide in the early hours (e.g., before 9 AM), suggesting there’s high uncertainty due to fewer data points.
#
# 2. Posting Patterns
# There’s a clear cluster between 10 AM – 3 PM, indicating that most posts happen during late morning to mid-afternoon.
#
# Very few posts occur before 8 AM or after 6 PM, so any trend there is not statistically reliable.
#
# 3. High-Impression Outliers
# There are several outlier posts with impressions above 15,000–20,000, especially around 10 AM, 11 AM, 1 PM, and 2 PM.
#
# These high-performing posts might be skewing the regression line upward — worth checking if they share similar content type or category.
#
# 4. Practical Insights
# Midday seems to be the sweet spot for posting (both frequency and some top-performers are there).
#
# Early morning and evening data are too sparse to draw strong conclusions, so we’d need more posts in those slots to confirm if they’re actually underperforming.

# %%
# Scatterplots with regression lines
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
x = df['Likes']
y = df['Impressions']
slope, intercept, r_value, p_value, std_err = linregress(x, y)
sns.regplot(data=df, x='Likes', y='Impressions', ax=axes[0], scatter_kws={'alpha':0.5})
axes[0].text(x.min(), y.max(), f'$R^2$ = {r_value**2:.3f}', fontsize=12, color='blue')

axes[0].set_title('Likes vs Impressions')

x = df['Comments']
y = df['Impressions']
slope, intercept, r_value, p_value, std_err = linregress(x, y)
sns.regplot(data=df, x='Comments', y='Impressions', ax=axes[1], scatter_kws={'alpha':0.5})
axes[1].text(x.min(), y.max(), f'$R^2$ = {r_value**2:.3f}', fontsize=12, color='blue')
axes[1].set_title('Comments vs Impressions')

x = df['Clicks']
y = df['Impressions']
slope, intercept, r_value, p_value, std_err = linregress(x, y)
sns.regplot(data=df, x='Clicks', y='Impressions', ax=axes[2], scatter_kws={'alpha':0.5})
axes[2].text(x.min(), y.max(), f'$R^2$ = {r_value**2:.3f}', fontsize=12, color='blue')
axes[2].set_title('Clicks vs Impressions')

plt.tight_layout()
plt.show()

# %% [markdown]
# Likes vs. Impressions:
#
# Strong positive linear trend: As likes increase, impressions rise sharply.
#
# The points are relatively tight around the regression line, indicating a strong correlation.
#
# Suggests that likes are a solid proxy for reach — either driving impressions or co-occurring due to high-quality content.
#
# Takeaway: Likes are a strong indicator or driver of impressions.

# %% [markdown]
# Comments vs. Impressions
#
# Still a positive trend, but noticeably weaker:
#
#     - Fewer comments overall (most points clustered below 5).
#
#     - The regression line is influenced by a few outliers (high-comment, high-impression posts).
#
# The wider confidence band shows higher variability and lower predictive power than likes.
#
# Takeaway: Comments may boost impressions, but are less consistent and more sparse.

# %% [markdown]
# Clicks vs. Impressions
#
# A strong positive correlation, similar in shape to the Likes plot.
#
# Some high click count outliers (e.g., 3000–5000 clicks) with correspondingly high impressions — these may skew the slope.
#
# The confidence band is tighter in the lower range (common values), suggesting reliability there.
#
# Takeaway: Clicks are also strongly associated with impressions, especially for high-performing posts.

# %%
# Boxplot of Impressions by Post Type

df2 = df.copy()
df2 = df2.dropna(subset=['Type of Post'])

plt.figure(figsize=(10,5))
sns.boxplot(data=df2, x='Type of Post', y='Impressions', hue='Type of Post', palette='Set2')
plt.title('Impressions by Post Type')
plt.show()
list_post = list(map(str,df2['Type of Post'].unique()))
for i in range(len(list_post)):
    impression_data = df2[df2['Type of Post'] == list_post[i]]['Impressions']
    min_value = impression_data.min()
    max_value = impression_data.max()
    range_value = max_value - min_value
    Q1 = impression_data.quantile(0.25)
    Q3 = impression_data.quantile(0.75)
    IQR = Q3 - Q1
    print(f"Statistics for {list_post[i]}:")
    print(f"  Min: {min_value}")
    print(f"  Max: {max_value}")    
    print(f"  Range: {range_value:}")
    print(f"  Q1: {Q1}")
    print(f"  Q3: {Q3}")
    print(f"  IQR: {IQR}")
data = {
    "Post Type": ['Video', 'Text', 'Image', 'Repost'],
    'Impressions Median': ['High', 'Moderate-High', 'Moderate', 'Very Low'],
    'Range & Outliers': ['Wide + strong outliers', 'Tight; consistent', 'Very high outliers', 'None'],
    "Performance Verdict": ['Best overall', 'Reliable', 'Volatile', 'Avoid']
}
display(pd.DataFrame(data))
# Out:
# Statistics for image:
#   Min: 923
#   Max: 20272
#   Range: 19349
#   Q1: 1866.75
#   Q3: 5331.25
#   IQR: 3464.5
# Statistics for text:
#   Min: 3485
#   Max: 8114
#   Range: 4629
#   Q1: 4203.75
#   Q3: 6026.5
#   IQR: 1822.75
# Statistics for video:
#   Min: 2260
#   Max: 19962
#   Range: 17702
#   Q1: 3518.0
#   Q3: 7812.0
#   IQR: 4294.0
# Statistics for repost:
#   Min: 1003
#   Max: 1253
#   Range: 250
#   Q1: 1065.5
#   Q3: 1190.5
#   IQR: 125.0
#   Post Type Impressions Median        Range & Outliers Performance Verdict
# 0     Video               High  Wide + strong outliers        Best overall
# 1      Text      Moderate-High       Tight; consistent            Reliable
# 2     Image           Moderate      Very high outliers            Volatile
# 3    Repost           Very Low                    None               Avoid

# %% [markdown]
# Video
#
#     IQR: 4294 → widest spread, indicating unpredictable performance.
#
#     Very high max (19,962) shows viral potential, but it’s not consistent.
#
#     Suitable for high-risk, high-reward strategy.
#
# Image
#
#     IQR: 3464.5, second highest.
#
#     Also has very high max (20,272), meaning images can perform very well.
#
#     Slightly more consistent than video, but still volatile.
#
# Text
#     IQR: 1822.75 → most consistent among high-performers.
#
#     Performance is tight and reliable, although not as explosive as video/image.
#
#     Best for steady reach without high variance.
#
# Repost
#
#     Extremely low IQR (125) and range.
#
#     Consistently low-performing, no outliers.
#
#     Likely not worth prioritizing unless strategic (e.g., internal resharing).

# %%
plt.figure(figsize=(12,5))
sns.barplot(data=df, x='Day of the week', y='Impressions', hue='Day of the week', order=['Mon','Tue','Wed','Thu','Fri'], estimator='mean', errorbar='sd', palette='Set2',  legend=False)
plt.title('Impressions by Day of Week')
plt.show()

data = {
    "Day of the Week": ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
    'Mean Impressions': ['Low', 'Slightly higher', 'Medium', 'High', 'Medium-High'],
    'Variability (SD)': ['Very High', 'High', 'Moderate', 'Very High', 'High'],
    'Interpretation': ['Inconsistent — some posts may perform well, others poorly. Not ideal.', 
                       'Slight improvement in average, but still variable.', 
                       'Better consistency; a more predictable day for impressions.', 
                       'Potentially strong day high average, but highly inconsistent.', 
                       'Similar to Tuesday — relatively good, but not stable.']
}
pd.set_option('display.max_colwidth', None)
display(pd.DataFrame(data))
# Out:
#   Day of the Week Mean Impressions Variability (SD)  \
# 0          Monday              Low        Very High
# 1         Tuesday  Slightly higher             High
# 2       Wednesday           Medium         Moderate
# 3        Thursday             High        Very High
# 4          Friday      Medium-High             High
#
#                                                           Interpretation
# 0  Inconsistent — some posts may perform well, others poorly. Not ideal.
# 1                     Slight improvement in average, but still variable.
# 2            Better consistency; a more predictable day for impressions.
# 3          Potentially strong day high average, but highly inconsistent.
# 4                  Similar to Tuesday — relatively good, but not stable.

# %% [markdown]
# Note: The Longer the vertical line the greater the standard deviation of how spread out the data is around the mean. Wednesday has the shortest vertical line meaning the mean impressions are consistent compared to Monday

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='Category', y='Impressions', hue='Category', palette='Set2')
plt.xticks(rotation=45)
plt.title('Impressions by Category')
plt.show()
list_category = list(map(str,df['Category'].unique()))
for i in range(len(list_category)):
    impression_data = df[df['Category'] == list_category[i]]['Impressions']
    min_value = impression_data.min()
    max_value = impression_data.max()
    range_value = max_value - min_value
    Q1 = impression_data.quantile(0.25)
    Q3 = impression_data.quantile(0.75)
    IQR = Q3 - Q1
    print(f"Statistics for {list_category[i]}:")
    print(f"  Min: {min_value}")
    print(f"  Max: {max_value}")    
    print(f"  Range: {range_value:}")
    print(f"  Q1: {Q1}")
    print(f"  Q3: {Q3}")
    print(f"  IQR: {IQR}")
# Out:
# Statistics for Internship:
#   Min: 1927
#   Max: 15092
#   Range: 13165
#   Q1: 4967.25
#   Q3: 9568.0
#   IQR: 4600.75
# Statistics for Trillium Cares:
#   Min: 1003
#   Max: 9070
#   Range: 8067
#   Q1: 2240.75
#   Q3: 4113.75
#   IQR: 1873.0
# Statistics for Culture:
#   Min: 923
#   Max: 11898
#   Range: 10975
#   Q1: 1408.25
#   Q3: 4430.75
#   IQR: 3022.5
# Statistics for Recruitment:
#   Min: 1031
#   Max: 20272
#   Range: 19241
#   Q1: 2164.0
#   Q3: 5781.5
#   IQR: 3617.5
# Statistics for Trading:
#   Min: 1557
#   Max: 19962
#   Range: 18405
#   Q1: 2519.0
#   Q3: 7493.0
#   IQR: 4974.0
# Statistics for Trainees:
#   Min: 4004
#   Max: 19672
#   Range: 15668
#   Q1: 5798.75
#   Q3: 13332.25
#   IQR: 7533.5
# Statistics for nan:
#   Min: nan
#   Max: nan
#   Range: nan
#   Q1: nan
#   Q3: nan
#   IQR: nan

# %% [markdown]
# Trainees
#     - Highest median impressions and widest range.
#
#     - This indicates both frequent high performance and some variability.
#
#     - A strong candidate category to focus on.
#
# Internship
#     - Performs well with high upper whiskers and a healthy cluster of above-median performers.
#
#     - Suggests solid engagement when posts are well-timed or well-written.
#
# Trillium Cares
#     - Lowest median and narrowest IQR (small spread).
#
#     - Might indicate niche interest or less engaging content.
#
#     - Opportunity: consider revamping content style or frequency.
#
# Culture & Recruitment
#     - Moderate to low medians with notable outliers.
#
#     - Some posts do well, but overall consistency is lacking.
#
#     - These categories might benefit from A/B testing headlines or media types.
#
# Trading
#     - Wide spread indicates inconsistent performance.
#
#     - Some posts gain traction, others don’t.
#
#     - Could be sensitive to timing, format, or audience interest shifts.

# %% [markdown]
# # **Step 4: Multiple Feature Relationships**

# %%
sns.pairplot(df, vars=['Impressions', 'Likes', 'Comments', 'Clicks'])
plt.show()

# %%
df_corr = df[['Impressions', 'Likes', 'Comments', 'Clicks']].dropna().corr()
df_corr
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >
